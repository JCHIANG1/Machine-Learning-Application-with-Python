# %% [markdown]
# ## PCA for Reduced Dimensionality in Clustering
# For this task I will experiment with using PCA as an approach to reduce dimensionality and noise in the data. Then compare the results of clustering the data with and without PCA using the provided image class assignments as the ground truth.

# %% [markdown]
# ### Data Set Information
# The data set used in this task is based on the Image Segmentation data set at the UCI Machine Learning Repository. The file "segmentation_data.txt" contains data about images with each line corresponding to one image. Each image is represented by 19 features (these are the columns in the data and correspond to the feature names in the file "segmentation_names.txt". The file "segmentation_classes.txt" contains the class labels (the type of image) and a numeric class label for each of the corresponding images in the data file.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### A. Load the Data
# 1. Load image data matrix (with rows as images and columns as features).
# 2. Load the numeric class labels from the segmentation class file.
# 3. Perform min-max normalization on the data matrix so that each feature is scaled to [0,1] range

# %%
data=pd.read_csv("C:/Users/Rai Chiang/Desktop/478 data/assignment4/Q1/segmentation_data.txt",header = None)
feature_name=pd.read_csv("C:/Users/Rai Chiang/Desktop/478 data/assignment4/Q1/segmentation_names.txt")
class_labels=pd.read_csv("C:/Users/Rai Chiang/Desktop/478 data/assignment4/Q1/segmentation_classes.txt",header = None)

# %%
from sklearn import preprocessing
MinMax=preprocessing.MinMaxScaler()
data_trans=MinMax.fit_transform(data)

# %% [markdown]
# ### B. Perform Kmeans clustering on the image data
# 1. Since there are a total 7 pre-assigned image classes, I try K = 7 in clustering.
# 2. Use Euclidean distance as the distance measure for the clustering.
# 3. Print the cluster centroids.
# 4. Compare 7 clusters to the 7 pre-assigned classes by computing the Completeness and Homogeneity values of the generated clusters.

# %%
from sklearn.cluster import KMeans
KMeans=KMeans(n_clusters=7, max_iter=500, verbose=1)
KMeans=KMeans.fit(data_trans)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 422.5804386140194
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 375.78242444517707
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 364.6887494121455
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 358.57050004147663
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 356.2373649149557
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 354.7874631827957
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 353.9337584364134
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 353.26175987295136
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 352.12475785340143
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 351.41863875215984
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 351.344633048776
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 351.2925171134479
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 351.24894160818974
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 351.1994523293091
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 351.05157138273023
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 350.7397521513925
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 350.22937122293166
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 350.05803966949475
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 350.03002648093286
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 350.025041469862
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 350.0173541333279
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 350.0129027194548
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 350.0129027194548
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 398.21269086951565
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 365.31154644081585
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 356.34243776554365
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 351.64972840562626
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 350.21274296645345
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 350.0480931585183
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 350.0155637868403
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 350.01207974106956
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 350.01207974106956
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 425.1823122684086
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 385.99654082584124
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 377.96356929924156
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 375.5160950224979
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 373.1359980279779
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 371.22050339434753
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 370.3816831555026
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 370.0246162353516
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 369.86248240177747
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 369.79407118037614
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 369.73192532432137
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 369.70038478145045
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 369.69356221549776
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 369.69055012165023
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 369.6877911401966
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 369.6877911401966
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 425.291768360152
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 404.7982763825364
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 396.59731894534224
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 388.89304323415
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 379.323134663313
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 373.8863575587296
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 370.223641652691
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 367.95339470002125
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 365.2923754538256
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 361.72701207748287
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 358.44219699612
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 355.9656747013328
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 354.41564418077843
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 353.6252736058642
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 352.74741003437157
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 351.65762144688654
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 351.3711496389625
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 351.31304417937207
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 351.2900301529347
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 351.24894160818974
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 351.1994523293091
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 351.05157138273023
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia
#  [0.26 0.39 0.   0.07 0.02 0.08 0.   0.06 0.   0.15 0.14 0.19 0.12 0.72 0.34 0.36 0.19 0.41 0.2 ]
#  [0.25 0.46 0.   0.03 0.01 0.04 0.   0.03 0.   0.03 0.02 0.04 0.02 0.77 0.22 0.51 0.04 0.8  0.18]
#  [0.3  0.53 0.   0.05 0.05 0.1  0.01 0.08 0.01 0.4  0.37 0.47 0.35 0.5  0.57 0.21 0.47 0.3  0.16]
#  [0.77 0.43 0.   0.01 0.02 0.04 0.   0.02 0.   0.04 0.04 0.06 0.03 0.78 0.22 0.49 0.06 0.54 0.24]]

# %%
from sklearn.metrics import completeness_score, homogeneity_score
class_labels=np.array(class_labels).reshape(-1)

print completeness_score(class_labels,predict_clusters)
print homogeneity_score(class_labels,predict_clusters)
# Out:
# 0.6131870124853012
# 0.6115021163370863

# %% [markdown]
# ### C. Perform PCA on the Normalized Image Data Matrix.
# 1. Analyze the principal components to determine the number, r, of PCs needed to capture at least 95% of variance in the data.
# 2. Then use these r components as features to transform the data into a reduced dimension space.

# %%
from sklearn import decomposition
pca=decomposition.PCA(n_components=10)
pca_trains=pca.fit(data_trans).transform(data_trans)
print pca.explained_variance_ratio_   
#it seems that the first 6 eigen values can capture the variance of the data
# Out:
# [0.61 0.13 0.1  0.05 0.04 0.02 0.02 0.02 0.01 0.01]

# %% [markdown]
# ### D. Perform Kmeans Again on the Lower Dimensional Transformed Data
# 1. Compute the Completeness and Homogeneity values of the new clusters

# %% [markdown]
# #### A clustering result satisfies homogeneity if all of its clusters contain only data points which are members of a single class.On the other hand,a clustering result satisfies completeness if all the data points that are members of a given class are elements of the same cluster. With the display scores below, I find that after applying the pca to transform the data, both homofeneity score and completeness score does not increase, which suggests that the lower dimension data representation captures most of the variance from the original data.

# %%
from sklearn.cluster import KMeans
KMeans1=KMeans(n_clusters=7, max_iter=500, verbose=1)
KMeans1=KMeans1.fit(pca_trains)
preddict_class_pca=KMeans1.predict(pca_trains)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 421.10953220024186
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 407.7542808926719
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 397.10503953598635
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 373.3479342997225
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 368.74163733754705
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 367.49011311416984
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 365.7836456031216
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 364.8852565002595
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 364.51688414923717
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 364.27531546532276
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 364.16446885603045
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 364.1043647731261
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 364.06732396453253
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 364.0539555424183
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 364.018285702473
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 364.0151394893342
# center shift 2.477290e-03 within tolerance 7.837848e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 385.3805444169934
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 356.96804240167853
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 350.33855168984076
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 346.94935020706805
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 343.6621814708285
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 342.13622898027063
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 341.6742323109608
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 341.28028245300584
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 340.8274168321457
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 340.29459440748155
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 340.1804302979722
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 340.151222258927
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 340.14733488667173
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 340.1406237932224
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 340.13242092187994
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 340.13242092187994
# center shift 0.000000e+00 within tolerance 7.837848e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 388.4707171104191
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 369.0495610813714
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 364.3849069685018
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 363.3071093282566
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 363.10561033961824
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 362.8748946629163
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 362.5408330491939
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 361.9116861584047
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 361.4528324399963
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 360.5778772335635
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 358.9405780871724
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia